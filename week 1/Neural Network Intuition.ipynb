# %% [markdown]
# # Part I: Neurons and the Brain

# %% [markdown]
# **Neural Networks**
# - Origins: Algorithms to mimic the brain
# - Applications: speech recognition, image processing, natural language processing, etc

# %% [markdown]
# **Mathematical of a Neuron**
# ![image.png](attachment:image.png)
# - A neuron takes on inputs (numbers), does some computations, and input on a second neuron
# - Simulate many neurons at the same time

# %% [markdown]
# **Advantages of Neural Networks**
# ![image.png](attachment:image.png)

# %% [markdown]
# # Part II: Demand Prediction

# %% [markdown]
# **A simple example**
# ![image.png](attachment:image.png)
# - Recalling logistic regression:
# a = f(x) = $\frac{1}{1 + e^{-(wx + b)}}$
# where a is also called "activation"
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **A complex example**
# ![image.png](attachment:image.png)
# - We have 4 features, denoted as yellow, and we want to "engineer" them into 3 features, which is a combination of the initial features, and compute the probability
# - The first layer is called the "input layer", the middle ones are called "hidden layers", the last one is called the "output layers"
# - Notice that, in this example, the process from the hidden layer to the output layer, is simply logistic regression

# %% [markdown]
# **Multiple Hidden Layers**
# ![image.png](attachment:image.png)

# %% [markdown]
# # Part III: Example Recognizing Images

# %% [markdown]
# **Face Recognition**
# ![image.png](attachment:image.png)
# - We receive a 1000 x 1000 pixels image, denoted as the table above
# - If we were to stack a million of these pixels into a vector, we would get our input layer

# %% [markdown]
# ![image.png](attachment:image.png)
# - In this neural network, the first layer looks for small patterns, such as vertical, horizontal lights, etc
# - The second layer looks for slightly large facial features, such as eyes, nose, etc
# - And the last layer look at faces and compute the probability
# - Notice that each activation corresponds to increasing features' levels (in this case, pixels)
