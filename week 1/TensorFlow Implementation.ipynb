# %% [markdown]
# ## Part I: Inference in Code

# %% [markdown]
# ![image.png](attachment:image.png)
# - The task of coffee roasting is dependent on 2 variables: duration and time
# - Notice that only an area of duration and time (denoted by the triangle) would be qualified as a good coffee

# %% [markdown]
# **Build the model using TensorFlow**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Model for Digit Classification**
# ![image.png](attachment:image.png)

# %% [markdown]
# # Part II: Data in TensorFlow

# %% [markdown]
# **Note about Numpy Array**
# ![image.png](attachment:image.png)
# - In regression, we represent input features as these 1d matrices, or a vector, or a list of numbers
# - However, in TensorFlow, we represent all numbers as matrices

# %% [markdown]
# **Activation Vector**
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## Part III: Building a Neural Network

# %% [markdown]
# **What was seen earlier**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Building a neural network architecture**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Digit Classification Model**
# ![image.png](attachment:image.png)
