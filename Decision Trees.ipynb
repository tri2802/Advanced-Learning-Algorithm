# %% [markdown]
# # Part I: Decision Tree Model

# %% [markdown]
# **Cat Classification Example**
# ![image.png](attachment:image.png)

# %% [markdown]
# **Decision Tree**
# ![image.png](attachment:image.png)

# %% [markdown]
# # Part II: Learning Process

# %% [markdown]
# **Decision Tree Learning**
# 1) How to choose what feature to split at each node (maximize purity or minimize impurity)
# 2) When do we stop splitting:
# - When a node is 100% one class
# - When a splitting node resulting in a tree exceeding maximum depth
# - When improvements in purity score are below a threshold
# - When number of examples in a node is below a threshold
